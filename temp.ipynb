 0.0016, 0.0015, 0.0015, 0.0015, 0.0015]
train_confidence_rmse = [0.0361, 0.0358, 0.0356, 0.0355, 0.0351, 0.0347, 0.0332, 0.0341, 0.0332, 0.0335, 
                         0.0329, 0.0333, 0.0324, 0.0322, 0.0322, 0.0320, 0.0313, 0.0315, 0.0315, 0.0313, 
                         0.0312, 0.0306, 0.0303, 0.0303, 0.0300, 0.0305, 0.0298, 0.0299, 0.0300, 0.0303]
val_confidence_rmse = [0.0432, 0.0434, 0.0447, 0.0446, 0.0456, 0.0434, 0.0438, 0.0422, 0.0431, 0.0428, 
                       0.0424, 0.0449, 0.0416, 0.0400, 0.0429, 0.0413, 0.0418, 0.0401, 0.0419, 0.0402, 
                       0.0401, 0.0395, 0.0396, 0.0395, 0.0390, 0.0402, 0.0384, 0.0384, 0.0382, 0.0391]

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10), facecolor='white')
fig.suptitle('Training and Validation Metrics Over Epochs', fontsize=16)

# Plot Classification Loss
axs[0, 0].plot(epochs, train_classification_loss, label='Training Classification Loss', color='#1f77b4')
axs[0, 0].plot(epochs, val_classification_loss, label='Validation Classification Loss', color='#ff7f0e')
axs[0, 0].set_title('Classification Loss')
axs[0, 0].set_xlabel('Epoch')
axs[0, 0].set_ylabel('Classification Loss')
axs[0, 0].legend()
axs[0, 0].grid(True)
axs[0, 0].set_facecolor('white')

# Plot Classification Accuracy
axs[0, 1].plot(epochs, train_classification_accuracy, label='Training Classification Accuracy', color='#2ca02c')
axs[0, 1].plot(epochs, val_classification_accuracy, label='Validation Classification Accuracy', color='#d62728')
axs[0, 1].set_title('Classification Accuracy')
axs[0, 1].set_xlabel('Epoch')
axs[0, 1].set_ylabel('Classification Accuracy')
axs[0, 1].set_ylim(0.8, 1.0)
axs[0, 1].legend()
axs[0, 1].grid(True)
axs[0, 1].set_facecolor('white')

# Plot Confidence Loss
axs[1, 0].plot(epochs, train_confidence_loss, label='Training Confidence Loss', color='#9467bd')
axs[1, 0].plot(epochs, val_confidence_loss, label='Validation Confidence Loss', color='#8c564b')
axs[1, 0].set_title('Confidence Loss')
axs[1, 0].set_xlabel('Epoch')
axs[1, 0].set_ylabel('Confidence Loss')
axs[1, 0].legend()
axs[1, 0].grid(True)
axs[1, 0].set_facecolor('white')

# Plot Confidence RMSE
axs[1, 1].plot(epochs, train_confidence_rmse, label='Training Confidence RMSE', color='#e377c2')
axs[1, 1].plot(epochs, val_confidence_rmse, label='Validation Confidence RMSE', color='#7f7f7f')
axs[1, 1].set_title('Confidence RMSE')
axs[1, 1].set_xlabel('Epoch')
axs[1, 1].set_ylabel('Confidence RMSE')
axs[1, 1].legend()
axs[1, 1].grid(True)
axs[1, 1].set_facecolor('white')

# Adjust layout to prevent overlap
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Show the plot
plt.show()
